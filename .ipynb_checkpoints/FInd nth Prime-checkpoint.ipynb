# %%
def check_prime(n):
    flag = False
    for d in range(2, n, 1):
        if n % d == 0:
            flag = True
    return flag
count = 1
n = 2
found = False
while found is False:
    prime = check_prime(n)
    if prime is False:
        count = count + 1
        print(count, " ", n)
        n = n + 1
        if count == 10001:
            print(n)
            found = True
            break
    else:
        n += 1
# Out:
# 1   1
# 2   2
# 3   3
# 4   5
# 5   7
# 6   11
# 7   13
# 8   17
# 9   19
# 10   23
# 11   29
# 12   31
# 13   37
# 14   41
# 15   43
# 16   47
# 17   53
# 18   59
# 19   61
# 20   67
# 21   71
# 22   73
# 23   79
# 24   83
# 25   89
# 26   97
# 27   101
# 28   103
# 29   107
# 30   109
# 31   113
# 32   127
# 33   131
# 34   137
# 35   139
# 36   149
# 37   151
# 38   157
# 39   163
# 40   167
# 41   173
# 42   179
# 43   181
# 44   191
# 45   193
# 46   197
# 47   199
# 48   211
# 49   223
# 50   227
# 51   229
# 52   233
# 53   239
# 54   241
# 55   251
# 56   257
# 57   263
# 58   269
# 59   271
# 60   277
# 61   281
# 62   283
# 63   293
# 64   307
# 65   311
# 66   313
# 67   317
# 68   331
# 69   337
# 70   347
# 71   349
# 72   353
# 73   359
# 74   367
# 75   373
# 76   379
# 77   383
# 78   389
# 79   397
# 80   401
# 81   409
# 82   419
# 83   421
# 84   431
# 85   433
# 86   439
# 87   443
# 88   449
# 89   457
# 90   461
# 91   463
# 92   467
# 93   479
# 94   487
# ...
